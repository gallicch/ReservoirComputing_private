# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla P100-PCIE-16GB (UUID: GPU-80b806f5-f7cd-9fa6-f505-2c4c492eeb64)

# %%
import tensorflow as tf
from tensorflow import keras
from time import time

# %%
class ReservoirCell(keras.layers.Layer):
#builds a reservoir as a hidden dynamical layer for a recurrent neural network

    def __init__(self, units, 
                 input_scaling = 1.0, bias_scaling = 1.0,
                 spectral_radius =0.99, 
                 leaky = 1, activation = tf.nn.tanh,
                 **kwargs):
        self.units = units 
        self.state_size = units
        self.input_scaling = input_scaling 
        self.bias_scaling = bias_scaling
        self.spectral_radius = spectral_radius
        self.leaky = leaky #leaking rate
        self.activation = activation
        super().__init__(**kwargs)
        
    def build(self, input_shape):
        
        #build the input weight matrix
        self.kernel = tf.random.uniform(shape = (input_shape[-1], self.units), minval = -self.input_scaling, maxval = self.input_scaling)
              
        #build the recurrent weight matrix
        #uses circular law to determine the values of the recurrent weight matrix
        #rif. paper 
        # Gallicchio, Claudio, Alessio Micheli, and Luca Pedrelli. 
        # "Fast spectral radius initialization for recurrent neural networks."
        # INNS Big Data and Deep Learning conference. Springer, Cham, 2019.
        value  = (self.spectral_radius / np.sqrt(self.units)) * (6/np.sqrt(12))
        W = tf.random.uniform(shape = (self.units, self.units), minval = -value,maxval = value)
        self.recurrent_kernel = W                    
        
        #initialize the bias 
        self.bias = tf.random.uniform(shape = (self.units,), minval = -self.bias_scaling, maxval = self.bias_scaling)
        
        self.built = True


    def call(self, inputs, states):
        prev_output = states[0]

        input_part = tf.matmul(inputs, self.kernel)
        
        state_part = tf.matmul(prev_output, self.recurrent_kernel)
        if self.activation!=None:
            output = prev_output * (1-self.leaky) + self.activation(input_part+ self.bias+ state_part) * self.leaky
        else:
            output = prev_output * (1-self.leaky) + (input_part+ self.bias+ state_part) * self.leaky
        
        return output, [output]

# %%
class RingReservoirCell(keras.layers.Layer):
#builds a ring reservoir as a hidden dynamical layer for a recurrent neural network
#differently from a conventional reservoir layer, in this case the units in the recurrent
#layer are organized to form a cycle (i.e., a ring)


    def __init__(self, units, 
                 input_scaling = 1.0, bias_scaling = 1.0,
                 spectral_radius =0.99, 
                 leaky = 1, activation = tf.nn.tanh,
                 **kwargs):
        self.units = units
        self.state_size = units
        self.input_scaling = input_scaling
        self.bias_scaling = bias_scaling
        self.spectral_radius = spectral_radius
        self.leaky = leaky
        self.activation = activation
        super().__init__(**kwargs)
        
    def build(self, input_shape):
        
        #build the input weight matrix
        self.kernel = tf.random.uniform(shape = (input_shape[-1], self.units), minval = -self.input_scaling, maxval = self.input_scaling)
              
        #build the recurrent weight matrix
        I = tf.linalg.eye(self.units)
        W = self.spectral_radius * tf.concat([I[:,-1:],I[:,0:-1]],axis = 1)

        self.recurrent_kernel = W                    
        
        self.bias = tf.random.uniform(shape = (self.units,), minval = -self.bias_scaling, maxval = self.bias_scaling)
        
        self.built = True


    def call(self, inputs, states):
        prev_output = states[0]

        input_part = tf.matmul(inputs, self.kernel)
        
        state_part = tf.matmul(prev_output, self.recurrent_kernel)
        if self.activation!=None:
            output = prev_output * (1-self.leaky) + self.activation(input_part+ self.bias+ state_part) * self.leaky
        else:
            output = prev_output * (1-self.leaky) + (input_part+ self.bias+ state_part) * self.leaky
        
        return output, [output]

# %%
class ESN(keras.Model):

    def __init__(self, units, output_units, output_activation,
                 input_scaling = 1., bias_scaling = 1.0, spectral_radius = 0.9,
                 leaky = 1, 
                 activation = tf.nn.tanh,
                 **kwargs):
        
        super().__init__(**kwargs)
        
        self.reservoir = keras.Sequential([
                    keras.layers.Masking(),
                    keras.layers.RNN(cell = ReservoirCell(units = units,
                                                          input_scaling = input_scaling,
                                                          bias_scaling = bias_scaling,
                                                          spectral_radius = spectral_radius,
                                                          leaky = leaky))
        ])
        self.readout = keras.Sequential([
            keras.layers.Dense(output_units, activation = output_activation)
        ])   
        
       
        
    def call(self, inputs):
        reservoir_states = self.reservoir(inputs)
        output = self.readout(reservoir_states)
        return output
    
    def fit(self, x, y, **kwargs):
        #applies the reservoirs to all the input sequences in the training set
        x_train_1 = self.reservoir(x)
        
        #does the same for the validation set
        x_val,y_val = kwargs['validation_data']
        x_val_1 = self.reservoir(x_val)
        kwargs['validation_data'] = (x_val_1, y_val)
        
        #trains the readout with the reservoir states just computed
        return self.readout.fit(x_train_1,y,**kwargs)
        
    def evaluate(self, x, y, **kwargs):
        x_train_1 = self.reservoir(x)
        return self.readout.evaluate(x_train_1,y,**kwargs)

# %%
class RESN(keras.Model):

    def __init__(self, units, output_units, output_activation,
                 input_scaling = 1., bias_scaling = 1.0, spectral_radius = 0.9,
                 leaky = 1, 
                 activation = tf.nn.tanh,
                 **kwargs):
        
        super().__init__(**kwargs)
        
        self.reservoir = keras.Sequential([
                    keras.layers.Masking(),
                    keras.layers.RNN(cell = RingReservoirCell(units = units,
                                                          input_scaling = input_scaling,
                                                          bias_scaling = bias_scaling,
                                                          spectral_radius = spectral_radius,
                                                          leaky = leaky))
        ])
        self.readout = keras.Sequential([
            keras.layers.Dense(output_units, activation = output_activation)
        ])   
        
       
        
    def call(self, inputs):
        reservoir_states = self.reservoir(inputs)
        output = self.readout(reservoir_states)
        return output
    
    def fit(self, x, y, **kwargs):
        x_train_1 = self.reservoir(x)
               
        x_val,y_val = kwargs['validation_data']
        x_val_1 = self.reservoir(x_val)
        kwargs['validation_data'] = (x_val_1, y_val)
        
        return self.readout.fit(x_train_1,y,**kwargs)
        
    def evaluate(self, x, y, **kwargs):
        x_train_1 = self.reservoir(x)
        return self.readout.evaluate(x_train_1,y,**kwargs)

# %%
pip install keras-tuner --upgrade
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.1.0-py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 5.8 MB/s
# Collecting kt-legacy
#   Downloading kt_legacy-1.0.4-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from keras-tuner) (21.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from keras-tuner) (1.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from keras-tuner) (2.23.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/dist-packages (from keras-tuner) (5.5.0)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.7/dist-packages (from keras-tuner) (2.7.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from keras-tuner) (1.19.5)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (5.1.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (4.4.2)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (4.8.0)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (0.8.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (1.0.18)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (57.4.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (2.6.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->keras-tuner) (1.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->keras-tuner) (0.2.5)
# Requirement already satisfied: pyparsing<3,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->keras-tuner) (2.4.7)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->ipython->keras-tuner) (0.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->keras-tuner) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->keras-tuner) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->keras-tuner) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->keras-tuner) (2.10)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (3.3.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (0.6.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (0.37.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (0.12.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (1.35.0)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (3.17.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (1.8.0)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (1.41.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (1.0.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras-tuner) (1.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard->keras-tuner) (4.8.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->keras-tuner) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras-tuner) (3.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard->keras-tuner) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard->keras-tuner) (3.10.0.2)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.1.0 kt-legacy-1.0.4

# %%
from keras_tuner.tuners import RandomSearch
from keras_tuner.tuners import BayesianOptimization
from keras_tuner.tuners import Hyperband
import numpy as np

num_epochs = 200
num_guesses = 5
patience = 10
max_units = 200

# %%
# !pip install sktime
# Out:
# Collecting sktime
#   Downloading sktime-0.8.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.1 MB)
#      |████████████████████████████████| 6.1 MB 15.0 MB/s
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from sktime) (1.1.5)
# Collecting statsmodels>=0.12.1
#   Downloading statsmodels-0.13.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 44.4 MB/s
# Requirement already satisfied: scikit-learn>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from sktime) (1.0.1)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.7/dist-packages (from sktime) (1.19.5)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from sktime) (0.37.0)
# Requirement already satisfied: statsmodels<=0.12.1 in /usr/local/lib/python3.7/dist-packages (from sktime) (0.10.2)
# Collecting numba>=0.53
#   Downloading numba-0.54.1-cp37-cp37m-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 50.9 MB/s
# Collecting llvmlite<0.38,>=0.37.0rc1
#   Downloading llvmlite-0.37.0-cp37-cp37m-manylinux2014_x86_64.whl (26.3 MB)
#      |████████████████████████████████| 26.3 MB 1.3 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.53->sktime) (57.4.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.0->sktime) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.0->sktime) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.1.0->sktime) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.0->sktime) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.0->sktime) (3.0.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.0->sktime) (1.4.1)
# Requirement already satisfied: patsy>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from statsmodels<=0.12.1->sktime) (0.5.2)
# Installing collected packages: llvmlite, numba, sktime
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.34.0
#     Uninstalling llvmlite-0.34.0:
#       Successfully uninstalled llvmlite-0.34.0
#   Attempting uninstall: numba
#     Found existing installation: numba 0.51.2
#     Uninstalling numba-0.51.2:
#       Successfully uninstalled numba-0.51.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sktime 0.8.1 requires statsmodels>=0.12.1, but you have statsmodels 0.10.2 which is incompatible.
# Successfully installed llvmlite-0.37.0 numba-0.54.1 sktime-0.8.1

# %%
from time_series_datasets import *

# %%
#load the dataset
#data = load_char_dataset()
#x_train_all,y_train_all,x_test,y_test,num_features = data[0], data[1], data[2], data[3], data[4]

x_train_all, y_train_all = load_sktime_dataset('CharacterTrajectories_TRAIN.ts')
x_test, y_test = load_sktime_dataset('CharacterTrajectories_TEST.ts')


from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(x_train_all, y_train_all, test_size=0.33, random_state=42)

#set the following values based on the specific dataset
output_units = 20
output_activation = 'softmax'
loss_function = 'sparse_categorical_crossentropy'

# %%
tf.random.set_seed(42)
#build the RC model
def build_model_ESN(hp):
    model = ESN(units = hp.Int('units', min_value = 5, max_value = max_units),
                output_units = output_units, 
                output_activation = output_activation,
                input_scaling = hp.Float('input_scaling', min_value = 0.1, max_value = 1.5, step = 0.1),
                bias_scaling = hp.Float('bias_scaling', min_value = 0.1, max_value = 1.5, step = 0.1),
                spectral_radius = hp.Float('spectral_radius', min_value = 0.1, max_value = 1.5, step = 0.1),
                leaky = hp.Float('leaky', min_value = 0.1, max_value = 1, step = 0.1))
    model.readout.compile(
        optimizer=keras.optimizers.RMSprop(
            hp.Float('learning_rate',min_value = 1e-5,max_value = 1e-1, sampling = 'log')),
        loss=loss_function,
        metrics=['accuracy'])
    return model



tuner = Hyperband(
    build_model_ESN,
    objective='val_accuracy',
    max_epochs = num_epochs,
    directory='Char_ESN_hyperband_c',
    project_name='RC toolbox',
    hyperband_iterations = 1,
    seed = 42)

tuner.search(x_train, y_train,
             epochs=num_epochs,
             validation_data = (x_val,y_val),callbacks=[keras.callbacks.EarlyStopping(monitor='val_loss', patience = patience)])


#choose the best hyper-parameters
best_model_hp = tuner.get_best_hyperparameters()[0]
acc_ts = []
required_time = []
tf.random.set_seed(42)
for i in range(num_guesses):
  initial_time = time()
  model = tuner.hypermodel.build(best_model_hp)
  model.fit(x_train, y_train, epochs = num_epochs, validation_data = (x_val, y_val),callbacks=[keras.callbacks.EarlyStopping(monitor='val_loss', patience = patience, restore_best_weights = True)])
  _, acc = model.evaluate(x_test,y_test)
  required_time.append(time()-initial_time)
  acc_ts.append(acc)

print('--C--')
print('Results standard RC: MEAN {} STD {}'.format(np.mean(acc_ts),np.std(acc_ts)))
print('----- required time: MEAN {} STD {}'.format(np.mean(required_time),np.std(required_time)))
model.readout.summary()
# Out:
# Trial 94 Complete [00h 00m 01s]
# val_accuracy: 0.03617021441459656
#
# Best val_accuracy So Far: 0.35531914234161377
# Total elapsed time: 00h 02m 32s
#
# Search: Running Trial #95
#
# Hyperparameter    |Value             |Best Value So Far
# units             |148               |120
# input_scaling     |1.1               |0.9
# bias_scaling      |0.3               |0.2
# spectral_radius   |1                 |1.3
# leaky             |0.5               |0.7
# learning_rate     |0.0014947         |0.020881
# tuner/epochs      |3                 |3
# tuner/initial_e...|0                 |0
# tuner/bracket     |4                 |4
# tuner/round       |0                 |0

# %%
tf.random.set_seed(42)
#build the RC model
def build_model_RESN(hp):
    model = RESN(units = hp.Int('units', min_value = 5, max_value = max_units),
                output_units = output_units, 
                output_activation = output_activation,
                input_scaling = hp.Float('input_scaling', min_value = 0.1, max_value = 1.5, step = 0.1),
                bias_scaling = hp.Float('bias_scaling', min_value = 0.1, max_value = 1.5, step = 0.1),
                spectral_radius = hp.Float('spectral_radius', min_value = 0.1, max_value = 1.5, step = 0.1),
                leaky = hp.Float('leaky', min_value = 0.1, max_value = 1, step = 0.1))
    model.readout.compile(
        optimizer=keras.optimizers.RMSprop(
            hp.Float('learning_rate',min_value = 1e-5,max_value = 1e-1, sampling = 'log')),
        loss=loss_function,
        metrics=['accuracy'])
    return model



tuner = Hyperband(
    build_model_RESN,
    objective='val_accuracy',
    max_epochs = num_epochs,
    directory='Char_RESN_hyperband_c',
    project_name='RC toolbox',
    seed = 42)

tuner.search(x_train, y_train,
             epochs=num_epochs,
             validation_data = (x_val,y_val),callbacks=[keras.callbacks.EarlyStopping(monitor='val_loss', patience = patience)])


#choose the best hyper-parameters
best_model_hp = tuner.get_best_hyperparameters()[0]
acc_ts = []
required_time = []
tf.random.set_seed(42)
for i in range(num_guesses):
  initial_time = time()
  model = tuner.hypermodel.build(best_model_hp)
  model.fit(x_train, y_train, epochs = num_epochs, validation_data = (x_val, y_val),callbacks=[keras.callbacks.EarlyStopping(monitor='val_loss', patience = patience, restore_best_weights = True)])
  _, acc = model.evaluate(x_test,y_test)
  required_time.append(time()-initial_time)
  acc_ts.append(acc)

print('--C--')
print('Results ring RC: MEAN {} STD {}'.format(np.mean(acc_ts),np.std(acc_ts)))
print('----- required time: MEAN {} STD {}'.format(np.mean(required_time),np.std(required_time)))
model.readout.summary()
# Out:
# Trial 254 Complete [00h 00m 42s]
# val_accuracy: 0.37659573554992676
#
# Best val_accuracy So Far: 0.9021276831626892
# Total elapsed time: 00h 15m 47s
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/200
# 30/30 [==============================] - 0s 8ms/step - loss: 2.8562 - accuracy: 0.2805 - val_loss: 1.8835 - val_accuracy: 0.3702
# Epoch 2/200
# 30/30 [==============================] - 0s 4ms/step - loss: 1.6827 - accuracy: 0.4359 - val_loss: 1.8496 - val_accuracy: 0.4532
# Epoch 3/200
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3139 - accuracy: 0.5725 - val_loss: 1.2002 - val_accuracy: 0.5957
# Epoch 4/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.2126 - accuracy: 0.5903 - val_loss: 1.0203 - val_accuracy: 0.6383
# Epoch 5/200
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0119 - accuracy: 0.6628 - val_loss: 1.0343 - val_accuracy: 0.6745
# Epoch 6/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.9682 - accuracy: 0.6744 - val_loss: 0.8579 - val_accuracy: 0.6979
# Epoch 7/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.8911 - accuracy: 0.7185 - val_loss: 0.8357 - val_accuracy: 0.7000
# Epoch 8/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.8170 - accuracy: 0.7237 - val_loss: 1.0913 - val_accuracy: 0.6574
# Epoch 9/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.7507 - accuracy: 0.7374 - val_loss: 0.8210 - val_accuracy: 0.7277
# Epoch 10/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0
200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.2064 - accuracy: 0.9359 - val_loss: 0.4536 - val_accuracy: 0.8809
# Epoch 50/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1852 - accuracy: 0.9370 - val_loss: 0.4191 - val_accuracy: 0.9128
# Epoch 51/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1807 - accuracy: 0.9412 - val_loss: 0.3781 - val_accuracy: 0.8872
# Epoch 52/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1658 - accuracy: 0.9433 - val_loss: 0.3967 - val_accuracy: 0.8957
# 45/45 [==============================] - 0s 2ms/step - loss: 0.3750 - accuracy: 0.9067
# Epoch 1/200
# 30/30 [==============================] - 0s 7ms/step - loss: 2.7293 - accuracy: 0.3004 - val_loss: 1.7802 - val_accuracy: 0.4277
# Epoch 2/200
# 30/30 [==============================] - 0s 4ms/step - loss: 1.5577 - accuracy: 0.4790 - val_loss: 1.7419 - val_accuracy: 0.4809
# Epoch 3/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.2386 - accuracy: 0.5945 - val_loss: 1.0519 - val_accuracy: 0.6745
# Epoch 4/200
# 30/30 [==============================] - 0s 4ms/step - loss: 1.1079 - accuracy: 0.6187 - val_loss: 0.9178 - val_accuracy: 0.7021
# Epoch 5/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.9191 - accuracy: 0.6870 - val_loss: 1.0311 - val_accuracy: 0.6468
# Epoch 6/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.9001 - accuracy: 0.6849 - val_loss: 0.7943 - val_accuracy: 0.7340
# Epoch 7/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.8027 - accuracy: 0.7185 - val_loss: 0.8522 - val_accuracy: 0.6745
# Epoch 8/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7348 - accuracy: 0.7384 - val_loss: 1.1387 - val_accuracy: 0.6298
# Epoch 9/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6878 - accuracy: 0.7794 - val_loss: 0.7866 - val_accuracy: 0.7681
# Epoch 10/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6669 - accuracy: 0.7805 - val_loss: 0.6342 - val_accuracy: 0.8064
# Epoch 11/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5896 - accuracy: 0.7920 - val_loss: 0.7008 - val_accuracy: 0.7745
# Epoch 12/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5576 - accuracy: 0.8025 - val_loss: 0.5127 - val_accuracy: 0.8404
# Epoch 13/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5414 - accuracy: 0.8288 - val_loss: 0.5797 - val_accuracy: 0.7979
# Epoch 14/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5325 - accuracy: 0.8120 - val_loss: 0.6124 - val_accuracy: 0.7787
# Epoch 15/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.4730 - accuracy: 0.8372 - val_loss: 0.6991 - val_accuracy: 0.7596
# Epoch 16/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4547 - accuracy: 0.8540 - val_loss: 0.5920 - val_accuracy: 0.8447
# Epoch 17/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4525 - accuracy: 0.8424 - val_loss: 0.6507 - val_accuracy: 0.8043
# Epoch 18/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.4327 - accuracy: 0.8487 - val_loss: 0.4585 - val_accuracy: 0.8596
# Epoch 19/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.4198 - accuracy: 0.8529 - val_loss: 0.5951 - val_accuracy: 0.8106
# Epoch 20/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.4036 - accuracy: 0.8645 - val_loss: 0.4845 - val_accuracy: 0.8404
# Epoch 21/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.3919 - accuracy: 0.8761 - val_loss: 0.3587 - val_accuracy: 0.8809
# Epoch 22/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.3646 - accuracy: 0.8761 - val_loss: 0.4880 - val_accuracy: 0.8574
# Epoch 23/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.3915 - accuracy: 0.8613 - val_loss: 0.4331 - val_accuracy: 0.8574
# Epoch 24/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.3916 - accuracy: 0.8676 - val_loss: 0.5093 - val_accuracy: 0.8213
# Epoch 25/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.3334 - accuracy: 0.8876 - val_loss: 0.4490 - val_accuracy: 0.8638
# Epoch 26/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.2997 - accuracy: 0.9002 - val_loss: 0.9370 - val_accuracy: 0.7234
# Epoch 27/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.3208 - accuracy: 0.8908 - val_loss: 0.3932 - val_accuracy: 0.8638
# Epoch 28/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.3134 - accuracy: 0.8950 - val_loss: 0.3618 - val_accuracy: 0.8830
# Epoch 29/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.2838 - accuracy: 0.9034 - val_loss: 0.5143 - val_accuracy: 0.8319
# Epoch 30/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.3190 - accuracy: 0.8855 - val_loss: 0.6506 - val_accuracy: 0.7851
# Epoch 31/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.3298 - accuracy: 0.8834 - val_loss: 0.4544 - val_accuracy: 0.8553
# 45/45 [==============================] - 0s 2ms/step - loss: 0.4115 - accuracy: 0.8823
# Epoch 1/200
# 30/30 [==============================] - 0s 7ms/step - loss: 2.8937 - accuracy: 0.2952 - val_loss: 1.8462 - val_accuracy: 0.3851
# Epoch 2/200
# 30/30 [==============================] - 0s 4ms/step - loss: 1.7276 - accuracy: 0.4517 - val_loss: 2.1485 - val_accuracy: 0.4447
# Epoch 3/200
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3729 - accuracy: 0.5704 - val_loss: 1.5068 - val_accuracy: 0.5553
# Epoch 4/200
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3061 - accuracy: 0.5924 - val_loss: 1.2091 - val_accuracy: 0.5979
# Epoch 5/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0941 - accuracy: 0.6534 - val_loss: 1.1197 - val_accuracy: 0.6170
# Epoch 6/200
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0416 - accuracy: 0.6712 - val_loss: 1.2174 - val_accuracy: 0.6064
# Epoch 7/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.9609 - accuracy: 0.6996 - val_loss: 0.9621 - val_accuracy: 0.6723
# Epoch 8/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.9257 - accuracy: 0.7048 - val_loss: 1.0890 - val_accuracy: 0.6809
# Epoch 9/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.8307 - accuracy: 0.7269 - val_loss: 0.8397 - val_accuracy: 0.7298
# Epoch 10/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.7893 - accuracy: 0.7426 - val_loss: 0.8154 - val_accuracy: 0.7298
# Epoch 11/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7281 - accuracy: 0.7553 - val_loss: 0.7453 - val_accuracy: 0.7660
# Epoch 12/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.7077 - accuracy: 0.7658 - val_loss: 0.7920 - val_accuracy: 0.7383
# Epoch 13/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.6844 - accuracy: 0.7794 - val_loss: 0.7525 - val_accuracy: 0.7468
# Epoch 14/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.6640 - accuracy: 0.7899 - val_loss: 0.6006 - val_accuracy: 0.8191
# Epoch 15/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.6174 - accuracy: 0.7931 - val_loss: 0.6974 - val_accuracy: 0.7660
# Epoch 16/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.5627 - accuracy: 0.8151 - val_loss: 0.8937 - val_accuracy: 0.7404
# Epoch 17/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5740 - accuracy: 0.8078 - val_loss: 0.6212 - val_accuracy: 0.8128
# Epoch 18/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.5344 - accuracy: 0.8193 - val_loss: 0.8416 - val_accuracy: 0.7426
# Epoch 19/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5313 - accuracy: 0.8204 - val_loss: 1.0939 - val_accuracy: 0.7106
# Epoch 20/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.5066 - accuracy: 0.8351 - val_loss: 0.6203 - val_accuracy: 0.7830
# Epoch 21/200
# 30/30 [==============================] - 0s 6ms/step - loss: 0.4953 - accuracy: 0.8235 - val_loss: 0.6038 - val_accuracy: 0.8000
# Epoch 22/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4854 - accuracy: 0.8267 - val_loss: 0.6165 - val_accuracy: 0.8106
# Epoch 23/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.4696 - accuracy: 0.8393 - val_loss: 0.5357 - val_accuracy: 0.8191
# Epoch 24/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5107 - accuracy: 0.8340 - val_loss: 0.5832 - val_accuracy: 0.8064
# Epoch 25/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4075 - accuracy: 0.8613 - val_loss: 0.5688 - val_accuracy: 0.8085
# Epoch 26/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.3772 - accuracy: 0.8687 - val_loss: 0.7679 - val_accuracy: 0.7638
# Epoch 27/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.3892 - accuracy: 0.8624 - val_loss: 0.6128 - val_accuracy: 0.8170
# Epoch 28/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.3700 - accuracy: 0.8739 - val_loss: 0.4745 - val_accuracy: 0.8426
# Epoch 29/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.3779 - accuracy: 0.8666 - val_loss: 0.5138 - val_accuracy: 0.8404
# Epoch 30/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.3858 - accuracy: 0.8792 - val_loss: 0.6101 - val_accuracy: 0.8043
# Epoch 31/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.4140 - accuracy: 0.8582 - val_loss: 0.5584 - val_accuracy: 0.8085
# Epoch 32/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.3401 - accuracy: 0.8782 - val_loss: 0.4490 - val_accuracy: 0.8574
# Epoch 33/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.3703 - accuracy: 0.8687 - val_loss: 0.4781 - val_accuracy: 0.8553
# Epoch 34/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.3442 - accuracy: 0.8876 - val_loss: 0.5403 - val_accuracy: 0.8468
# Epoch 35/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.3345 - accuracy: 0.8918 - val_loss: 0.3768 - val_accuracy: 0.8851
# Epoch 36/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.3303 - accuracy: 0.8960 - val_loss: 0.5496 - val_accuracy: 0.8383
# Epoch 37/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.3563 - accuracy: 0.8718 - val_loss: 0.5090 - val_accuracy: 0.8489
# Epoch 38/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.3250 - accuracy: 0.8792 - val_loss: 0.3620 - val_accuracy: 0.8787
# Epoch 39/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.3137 - accuracy: 0.8897 - val_loss: 0.5923 - val_accuracy: 0.8064
# Epoch 40/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.2948 - accuracy: 0.8939 - val_loss: 0.4485 - val_accuracy: 0.8532
# Epoch 41/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.2837 - accuracy: 0.9023 - val_loss: 0.4612 - val_accuracy: 0.8596
# Epoch 42/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.3005 - accuracy: 0.8950 - val_loss: 0.4350 - val_accuracy: 0.8553
# Epoch 43/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.3124 - accuracy: 0.8897 - val_loss: 0.3781 - val_accuracy: 0.9000
# Epoch 44/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.2675 - accuracy: 0.9128 - val_loss: 0.4315 - val_accuracy: 0.8809
# Epoch 45/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.2866 - accuracy: 0.9023 - val_loss: 0.4137 - val_accuracy: 0.8851
# Epoch 46/200
# 30/30 [==============================] - 0s 5ms/step - loss: 0.3070 - accuracy: 0.9002 - val_loss: 0.5118 - val_accuracy: 0.8404
# Epoch 47/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.2568 - accuracy: 0.9223 - val_loss: 0.4546 - val_accuracy: 0.8851
# Epoch 48/200
# 30/30 [==============================] - 0s 4ms/step - loss: 0.2526 - accuracy: 0.9181 - val_loss: 0.5277 - val_accuracy: 0.8468
# 45/45 [==============================] - 0s 2ms/step - loss: 0.3191 - accuracy: 0.8990
# --C--
# Results ring RC: MEAN 0.8885793924331665 STD 0.015732605430363228
# ----- required time: MEAN 8.718524026870728 STD 2.4888867017666834
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 20)                3520
#
# =================================================================
# Total params: 3,520
# Trainable params: 3,520
# Non-trainable params: 0
# _________________________________________________________________
